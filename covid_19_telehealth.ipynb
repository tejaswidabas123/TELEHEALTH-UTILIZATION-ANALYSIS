# %% [markdown]
# #COVID-19 and the rise of Telemedicine, by the Medical Futurist
#
# Telemedicine has not had the success story it had hoped to achieve. The method, involving remote health-related services such as monitoring, advice and education between doctors and patients online over a secure connection, promised to be at the forefront of the future of medicine. It promised to make state-of-the-art healthcare more accessible without the need to wait hours in line.
#
# However, the reality is that only a handful of countries and regions adopted the concept, but telemedicine remains merely a concept for many. In fact, a study showed that in the U.S. alone, 82 percent of consumers do not use such services.
#
# Moreover, some even question its reliability and effectiveness. Put to blame is the very quality of these services. A study with researchers posing as patients found that remote doctors across 16 different telemedicine apps misdiagnosed serious skin conditions.https://medicalfuturist.com/covid-19-was-needed-for-telemedicine-to-finally-go-mainstream/

# %%
from IPython.display import Image
Image(url = 'data:image/png;base64,...',width=400,height=400)
# Out:
# <img src="data:image/png;base64,..." width="400" height="400"/>

# %% [markdown]
# thedoctors.com

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
import plotly.offline as py
import plotly.express as px


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/model-answers/Approaches_for_encouraging_and_facilitating.csv
# /kaggle/input/model-answers/Immune_response_and_immunity_eval.csv
# /kaggle/input/model-answers/Extracorporeal_membrane_oxygenation_(ECMO)_outcomes.csv
# /kaggle/input/model-answers/Immune_response_and_immunity.csv
# /kaggle/input/model-answers/Efforts_to_determine_adjunctive_and.csv
# /kaggle/input/model-answers/Effectiveness_of_personal_protective_equipment.csv
# /kaggle/input/model-answers/Outcomes_data_for_COVID-19_after.csv
# /kaggle/input/model-answers/Best_telemedicine_practices,_barriers_and.csv
# /kaggle/input/model-answers/Effectiveness_of_drugs_being_developed.csv
# /kaggle/input/model-answers/Seasonality_of_transmission_eval.csv
# /kaggle/input/model-answers/Severity_of_disease,_including_risk.csv
# /kaggle/input/model-answers/Age-adjusted_mortality_data_for_Acute.csv
# /kaggle/input/model-answers/Neonates_and_pregnant_women.csv
# /kaggle/input/model-answers/Approaches_to_evaluate_risk_for.csv
# /kaggle/input/model-answers/Physical_science_of_the_coronavirus_eval.csv
# /kaggle/input/model-answers/Co-infections__determine_whether_co-existing.csv
# /kaggle/input/model-answers/Range_of_incubation_periods_for.csv
# /kaggle/input/model-answers/Implementation_of_diagnostics_and_products.csv
# /kaggle/input/model-answers/Oral_medications_that_might_potentially.csv
# /kaggle/input/model-answers/Efforts_to_develop_prophylaxis_clinical.csv
# /kaggle/input/model-answers/Persistence_of_virus_on_surfaces.csv
# /kaggle/input/model-answers/Application_of_regulatory_standards_(e.g.,.csv
# /kaggle/input/model-answers/Susceptibility_of_population.csv
# /kaggle/input/model-answers/Effectiveness_of_movement_control_strategies.csv
# /kaggle/input/model-answers/Exploration_of_use_of_best.csv
# /kaggle/input/model-answers/Efforts_to_develop_animal_models.csv
# /kaggle/input/model-answers/Assays_to_evaluate_vaccine_immune.csv
# /kaggle/input/model-answers/Alternative_models_to_aid_decision.csv
# /kaggle/input/model-answers/Range_of_incubation_periods_for_eval.csv
# /kaggle/input/model-answers/Seasonality_of_transmission.csv
# /kaggle/input/model-answers/Socio-economic_and_behavioral_factors_to.csv
# /kaggle/input/model-answers/Implementation_of_diagnostics_and_products_eval.csv
# /kaggle/input/model-answers/Smoking_pre-existing_pulmonary_disease.csv
# /kaggle/input/model-answers/Public_health_mitigation_measures_that.csv
# /kaggle/input/model-answers/Mobilization_of_surge_medical_staff.csv
# /kaggle/input/model-answers/Natural_history_of_the_virus.csv
# /kaggle/input/model-answers/Persistence_of_virus_on_surfaces_eval.csv
# /kaggle/input/model-answers/Physical_science_of_the_coronavirus.csv
# /kaggle/input/model-answers/Natural_history_of_the_virus_eval.csv
# /kaggle/input/model-answers/Efforts_targeted_at_a_universal.csv
# /kaggle/input/model-answers/Effectiveness_of_movement_control_strategies_eval.csv
# /kaggle/input/model-answers/Knowledge_of_the_frequency,_manifestations,.csv
# /kaggle/input/model-answers/Methods_evaluating_potential_complication_of.csv
# /kaggle/input/model-answers/Use_of_AI_in_real-time.csv
# /kaggle/input/model-answers/Capabilities_to_discover_a_therapeutic.csv
# /kaggle/input/model-answers/Effectiveness_of_personal_protective_equipment_eval.csv
# /kaggle/input/model-answers/Role_of_the_environment_in_eval.csv
# /kaggle/input/model-answers/Clinical_and_bench_trials_to.csv
# /kaggle/input/model-answers/Role_of_the_environment_in.csv
# /kaggle/input/model-answers/Resources_to_support_skilled_nursing.csv

# %% [markdown]
# #And then came COVID-19…
#
# Let’s see how the COVID-19 forced the healthcare world to do a 180° on telemedicine and what awaits this technology in the future.
#
# Digital health fares as an adequate solution in these circumstances. Robots help in monitoring infected patients to limit contact with medical personnel, deliver medical supplies and disinfect wards.
#
# Remote consultation is also becoming an increasingly attractive option in healthcare. The COVID-19 pandemic brought telemedicine into a new light. As medical professionals need to stay healthy and disease-free, the need for remote technologies skyrocketed. Both the CDC and WHO are advocating for telemedicine to monitor patients and reduce risks of them spreading the virus by traveling to hospitals.
# https://medicalfuturist.com/covid-19-was-needed-for-telemedicine-to-finally-go-mainstream/

# %%
df = pd.read_csv("../input/model-answers/Best_telemedicine_practices,_barriers_and.csv")
df.head()
# Out:
#                                          question   section  \
# 0  How does telemedicine help manage the disease?  abstract
# 1  How does telemedicine help manage the disease?  abstract
# 2  How does telemedicine help manage the disease?  abstract
# 3  How does telemedicine help manage the disease?  abstract
# 4  How does telemedicine help manage the disease?  abstract
#
#                                               answer  start_score  end_score  \
# 0  preventing possible spread of COVID - 19 while...     2.427497   4.514661
# 1  enable patients to connect with their healthca...     1.333884   4.782465
# 2  Due to reduced outpatient capacity and the nee...     0.535503   2.013699
# 3  telemedicine consultations and return visits w...     0.391776   0.297626
# 4                outbreak alert and response network    -1.557408  -0.785203
#
#                                                state  \
# 0  [[[-0.09966467 -0.32724842 -1.1975589  ... -0....
# 1  [[[-0.0754891   0.3861072   0.03245347 ...  0....
# 2  [[[-0.2615807   0.56168985  0.38387188 ...  0....
# 3  [[[-0.04772362 -0.32055813 -1.1008934  ... -0....
# 4  [[[-0.09966467 -0.32724842 -1.1975589  ... -0....
#
#                                              context  \
# 0  Please cite this article as : A. Elkbuli, H. E...
# 1  Abstract The well - being of the health care w...
# 2  Abstract Our public pediatric tertiary hospita...
# 3  Abstract Purpose During a global pandemic the ...
# 4  The rapid spread of Coronavirus disease 2019 (...
#
#                                 doi  \
# 0        10.1016/j.ajem.2020.04.003
# 1         10.1016/j.jcv.2020.104345
# 2  10.1016/j.jadohealth.2020.03.037
# 3        10.1016/j.adro.2020.03.010
# 4       10.1101/2020.02.20.20025957
#
#                                              authors  \
# 0      Elkbuli, Adel; Ehrlich, Haley; McKenney, Mark
# 1  Moazzami, Bobak; Razavi-Khorasani, Niloofar; D...
# 2  Davis, Courtney; Chong, Ng Kee; Oh, Jean Yin; ...
# 3  Zaorsky, Nicholas G.; Yu, James B.; McBride, S...
# 4  Yunkai Zhai; Yichuan Wang; Minhao Zhang; Jody ...
#
#                                       journal publish_time  \
# 0  The American Journal of Emergency Medicine   2020-04-07
# 1                Journal of Clinical Virology   2020-04-04
# 2                Journal of Adolescent Health   2020-04-06
# 3              Advances in Radiation Oncology   2020-04-01
# 4                                         NaN   2020-02-23
#
#                                                title  \
# 0  The effective use of telemedicine to save live...
# 1  COVID-19 and Telemedicine: Immediate action re...
# 2  Caring for children and adolescents with eatin...
# 3  Prostate Cancer Radiotherapy Recommendations i...
# 4  From Isolation to Coordination: How Can Teleme...
#
#    cohort_size_from_abstract  cohort_size_from_body
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN

# %% [markdown]
# #A ready-made option
#
# Telehealth is bridging the gap between people, physicians and health systems, enabling everyone, especially symptomatic patients, to stay at home and communicate with physicians through virtual channels, helping to reduce the spread of the virus to mass populations and the medical staff on the frontlines.
#
# **** It’s a readily available solution that allows those following treatment for other conditions to continue doing so or even filter out potential COVID-19 cases remotely.****
# https://medicalfuturist.com/covid-19-was-needed-for-telemedicine-to-finally-go-mainstream/

# %%
fig,axes = plt.subplots(1,1,figsize=(20,5))
sns.heatmap(df.isna(),yticklabels=False,cbar=False,cmap='viridis')
plt.show()

# %%
df.dropna(how = 'all',inplace = True)
df.drop(['cohort_size_from_abstract', 'cohort_size_from_body'],axis=1,inplace = True)
df.shape
# Out:
# (20, 12)

# %% [markdown]
# #Codes from xhlulu https://www.kaggle.com/xhlulu/starter-covid-qa

# %%
px.histogram(df, x='answer', color='question')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dec165628822> in <cell line: 1>()
# ----> 1 px.histogram(df, x='answer', color='question')
#
# NameError: name 'px' is not defined

# %% [markdown]
# #Telemedicine companies are evolving with the times.
#
# Companies plan to release at-home COVID-19 testing kits. This can neatly tie in with their existing remote consultation services. Others offer free coronavirus risk assessments. These then direct high-risk patients towards a video or phone consultation with a physician.
#
# https://medicalfuturist.com/covid-19-was-needed-for-telemedicine-to-finally-go-mainstream/

# %%
px.histogram(df, x='section', color='publish_time')
# Out:
# <div>
#
#
#             <div id="fdf78f36-d273-4488-bc09-3e3e49bb14f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fdf78f36-d273-4488-bc09-3e3e49bb14f0")) {
#                     Plotly.newPlot(
#                         'fdf78f36-d273-4488-bc09-3e3e49bb14f0',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "publish_time=2020-04-07<br>section=%{x}<br>count=%{y}", "legendgroup": "2020-04-07", "marker": {"color": "#636efa"}, "name": "2020-04-07", "offsetgroup": "2020-04-07", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["abstract"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "publish_time=2020-04-04<br>section=%{x}<br>count=%{y}", "legendgroup": "2020-04-04", "marker": {"color": "#EF553B"}, "name": "2020-04-04", "offsetgroup": "2020-04-04", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["abstract", "abstract", "abstract"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "publish_time=2020-04-06<br>section=%{x}<br>count=%{y}", "legendgroup": "2020-04-06", "marker": {"color": "#00cc96"}, "name": "2020-04-06", "offsetgroup": "2020-04-06", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["abstract", "body_text/discussion", "abstract"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "publish_time=2020-04-01<br>section=%{x}<br>count=%{y}", "legendgroup": "2020-04-01", "marker": {"color": "#ab63fa"}, "name": "2020-04-01", "offsetgroup": "2020-04-01", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["abstract", "abstract"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "publish_time=2020-02-23<br>section=%{x}<br>count=%{y}", "legendgroup": "2020-02-23", "marker": {"color": "#FFA15A"}, "name": "2020-02-23", "offsetgroup": "2020-02-23", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["abstract"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "publish_time=2020-03-31<br>section=%{x}<br>count=%{y}", "legendgroup": "2020-03-31", "marker": {"color": "#19d3f3"}, "name": "2020-03-31", "offsetgroup": "2020-03-31", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["abstract", "abstract", "abstract"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "publish_time=2020-02-22<br>section=%{x}<br>count=%{y}", "legendgroup": "2020-02-22", "marker": {"color": "#FF6692"}, "name": "2020-02-22", "offsetgroup": "2020-02-22", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["abstract"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "publish_time=2020-03-23<br>section=%{x}<br>count=%{y}", "legendgroup": "2020-03-23", "marker": {"color": "#B6E880"}, "name": "2020-03-23", "offsetgroup": "2020-03-23", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["body_text/conclusion", "body_text/conclusion"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "publish_time=2020-03-12<br>section=%{x}<br>count=%{y}", "legendgroup": "2020-03-12", "marker": {"color": "#FF97FF"}, "name": "2020-03-12", "offsetgroup": "2020-03-12", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["body_text/conclusion"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "publish_time=2020-02-29<br>section=%{x}<br>count=%{y}", "legendgroup": "2020-02-29", "marker": {"color": "#FECB52"}, "name": "2020-02-29", "offsetgroup": "2020-02-29", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["body_text/conclusion"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "publ ...
#                         {"barmode": "relative", "legend": {"title": {"text": "publish_time"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0

# %% [markdown]
# #Overloaded
#
# Before the pandemic, only 1 in 10 US patients used telemedicine services, according to a J.D. Power survey. Now the tides have drastically changed.
#
# Stakeholders and patients alike are now scrambling to find a telemedicine service, a sector which is facing an unprecedented demand. Appointments via apps are up by 70%. Another service, had its app use increase by a whopping 158% in the US since January.https://medicalfuturist.com/covid-19-was-needed-for-telemedicine-to-finally-go-mainstream/

# %%
fig = px.histogram(df, x='doi', color='end_score')
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <div>
#
#
#             <div id="4e9dae29-ae13-430b-bbdb-766c5e57d663" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4e9dae29-ae13-430b-bbdb-766c5e57d663")) {
#                     Plotly.newPlot(
#                         '4e9dae29-ae13-430b-bbdb-766c5e57d663',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "end_score=4.514661312103272<br>doi=%{x}<br>count=%{y}", "legendgroup": "4.514661312103272", "marker": {"color": "#636efa"}, "name": "4.514661312103272", "offsetgroup": "4.514661312103272", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["10.1016/j.ajem.2020.04.003"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "end_score=4.782464504241943<br>doi=%{x}<br>count=%{y}", "legendgroup": "4.782464504241943", "marker": {"color": "#EF553B"}, "name": "4.782464504241943", "offsetgroup": "4.782464504241943", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["10.1016/j.jcv.2020.104345"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "end_score=2.01369857788086<br>doi=%{x}<br>count=%{y}", "legendgroup": "2.01369857788086", "marker": {"color": "#00cc96"}, "name": "2.01369857788086", "offsetgroup": "2.01369857788086", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["10.1016/j.jadohealth.2020.03.037"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "end_score=0.2976255416870117<br>doi=%{x}<br>count=%{y}", "legendgroup": "0.2976255416870117", "marker": {"color": "#ab63fa"}, "name": "0.2976255416870117", "offsetgroup": "0.2976255416870117", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["10.1016/j.adro.2020.03.010"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "end_score=-0.7852028012275696<br>doi=%{x}<br>count=%{y}", "legendgroup": "-0.7852028012275696", "marker": {"color": "#FFA15A"}, "name": "-0.7852028012275696", "offsetgroup": "-0.7852028012275696", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["10.1101/2020.02.20.20025957"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "end_score=-0.9244887232780457<br>doi=%{x}<br>count=%{y}", "legendgroup": "-0.9244887232780457", "marker": {"color": "#19d3f3"}, "name": "-0.9244887232780457", "offsetgroup": "-0.9244887232780457", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["10.1016/j.jpainsymman.2020.03.019"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "end_score=-2.047656774520874<br>doi=%{x}<br>count=%{y}", "legendgroup": "-2.047656774520874", "marker": {"color": "#FF6692"}, "name": "-2.047656774520874", "offsetgroup": "-2.047656774520874", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["10.1016/j.dsx.2020.04.001"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "end_score=-1.0265783071517944<br>doi=%{x}<br>count=%{y}", "legendgroup": "-1.0265783071517944", "marker": {"color": "#B6E880"}, "name": "-1.0265783071517944", "offsetgroup": "-1.0265783071517944", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["10.1016/j.jadohealth.2020.03.037"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "end_score=7.5166358947753915<br>doi=%{x}<br>count=%{y}", "legendgroup": "7.5166358947753915", "marker": {"color": "#FF97FF"}, "name": "7.5166358947753915", "offsetgroup": "7.5166358947753915", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["10.3390/jcm9020596"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "end_score=4.676680564880371<br>doi=%{x}<br>count=%{y}", "legendgroup": "4.676680564880371", "marker": {"color": "#FECB52"}, "name": "4.6766 ...

# %% [markdown]
# #Telemedicine services have the potential to overload hospitals but will significantly reduce additional pressure.
#
# Not all institutions have the equipment to deliver remote consultations and allocate the required staff and resources. In a pandemic where the medical staff itself gets infected and quarantined, the pool of available providers is even smaller. But even this is a two-sided coin.
#
# By deploying advanced telehealth solutions, physicians are expanding their reach – even if quarantined – with the ability to remotely examine and diagnose more patients in a shorter amount of time, minimizing the number of patients entering hospitals and medical facilities
# https://medicalfuturist.com/covid-19-was-needed-for-telemedicine-to-finally-go-mainstream/

# %%
fig = px.histogram(df, x='context', color='state')
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <div>
#
#
#             <div id="6e915b0a-d3a3-4a53-bbe5-8234d79eb007" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6e915b0a-d3a3-4a53-bbe5-8234d79eb007")) {
#                     Plotly.newPlot(
#                         '6e915b0a-d3a3-4a53-bbe5-8234d79eb007',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "state=[[[-0.09966467 -0.32724842 -1.1975589  ... -0.6428238  -0.08495279\n    0.09341696]\n  [ 0.13327341 -0.46352392 -1.4914044  ... -0.6966252  -0.6545675\n    0.6630803 ]\n  [ 0.13902642 -0.63502437 -1.5575625  ... -0.41508082 -0.62497777\n    0.8992547 ]\n  ...\n  [ 0.23726505 -0.82862836 -1.3015928  ... -0.67905426 -0.52093714\n    0.98743856]\n  [ 0.27573028 -0.8208754  -1.3185802  ... -0.66828793 -0.5453967\n    0.98274314]\n  [-0.03952388 -0.3587449  -1.2947593  ... -0.59276927 -0.33410496\n    0.78571165]]\n\n [[-0.14667247 -0.2666848  -1.6296796  ... -0.5532088  -0.18190548\n    0.29321003]\n  [-0.04962796 -0.47758847 -1.406855   ... -0.8174325  -0.61068404\n    0.4528885 ]\n  [-0.01508795 -0.6373212  -1.4246383  ... -0.59980154 -0.6663782\n    0.6351984 ]\n  ...\n  [ 0.22537342 -0.84116167 -1.2932308  ... -0.5967743  -0.49021655\n    0.9621977 ]\n  [ 0.20368068 -0.83982015 -1.3073518  ... -0.6206705  -0.48609653\n    0.9372385 ]\n  [ 0.09422606 -0.33785123 -1.2871388  ... -0.7761819  -0.17239387\n    0.8556263 ]]\n\n [[-0.26353818 -0.4523808  -1.4729533  ... -0.90704244 -0.29219317\n    0.46260425]\n  [ 0.03710892 -0.4866152  -1.4102988  ... -0.8758701  -0.71691215\n    0.49366388]\n  [-0.071464   -0.61091006 -1.4149013  ... -0.59787893 -0.7914523\n    0.668351  ]\n  ...\n  [ 0.17958272 -0.8284934  -1.3831116  ... -0.5557265  -0.38878524\n    0.9284012 ]\n  [ 0.15886655 -0.8401285  -1.3972095  ... -0.56440246 -0.43283638\n    0.9382047 ]\n  [-0.08761714 -0.3866135  -1.2458482  ... -0.6945011  -0.14597759\n    0.79908633]]\n\n ...\n\n [[-0.06636063  0.5229287   0.16243823 ... -0.10330735  0.47444242\n   -0.89210427]\n  [ 0.3294488  -0.32683876 -1.5453386  ... -0.51330733 -0.7439357\n    0.5682129 ]\n  [ 0.31823233 -0.49814913 -1.678404   ... -0.13611825 -0.77158934\n    0.5562749 ]\n  ...\n  [ 0.23875263 -0.75839424 -1.3618599  ... -0.5457455  -0.56711864\n    0.9205425 ]\n  [ 0.26622808 -0.76045895 -1.3905993  ... -0.5284728  -0.5785097\n    0.9160773 ]\n  [ 0.0284762  -0.15393701 -1.3487521  ... -0.5741176  -0.55962\n    0.7358786 ]]\n\n [[-0.26017547  0.51259804  0.43875542 ...  0.09562191  0.63902485\n   -1.0043774 ]\n  [ 0.43985522 -0.27885056 -1.6247891  ... -0.53649276 -0.88533837\n    0.47792357]\n  [ 0.44461736 -0.535082   -1.7874447  ... -0.14779362 -0.8475781\n    0.43080708]\n  ...\n  [ 0.25870082 -0.7915044  -1.4071386  ... -0.3899774  -0.5009365\n    0.843058  ]\n  [ 0.3065794  -0.7971171  -1.443847   ... -0.3555024  -0.5147331\n    0.84665364]\n  [ 0.06596458 -0.0953193  -1.2112858  ...  0.01601859 -0.51900494\n    0.7923351 ]]\n\n [[-0.02330059  0.47600108 -0.06402835 ...  0.26031575  0.04523568\n   -1.1165514 ]\n  [ 0.4094643  -0.2500575  -1.5656933  ... -0.5727597  -0.7256324\n    0.29467908]\n  [ 0.33788556 -0.5829585  -1.7392623  ... -0.15669389 -0.7451325\n    0.24726994]\n  ...\n  [ 0.24555676 -0.8002292  -1.336224   ... -0.36290738 -0.4868329\n    0.90280193]\n  [ 0.28539628 -0.8105905  -1.3554405  ... -0.35467464 -0.52314705\n    0.8940188 ]\n  [-0.00886068 -0.23686936 -1.2194637  ... -0.13492799 -0.582376\n    0.6891627 ]]]<br>context=%{x}<br>count=%{y}", "legendgroup": "[[[-0.09966467 -0.32724842 -1.1975589  ... -0.6428238  -0.08495279\n    0.09341696]\n  [ 0.13327341 -0.46352392 -1.4914044  ... -0.6966252  -0.6545675\n    0.6630803 ]\n  [ 0.13902642 -0.63502437 -1.5575625  ... -0.41508082 -0.62497777\n    0.8992547 ]\n  ...\n  [ 0.23726505 -0.82862836 -1.3015928  ... -0.67905426 -0.52093714\n    0.98743856]\n  [ 0.27573028 -0.8208754  -1.3185802  ... -0.66828793 -0.5453967\n    0.98274314]\n  [-0.03952388 -0.3587449  -1.2947593  ... -0.59276927 -0.33410496\n    0.78571165]]\n\n [[-0.14667247 -0.2666848  -1.6296796  ... -0.5532088  -0.18190548\n    0.29321003]\n  [-0.04962796 -0.47758847 -1.406855   ... -0.8174325  -0.61068404\n    0.4528885 ]\n  [-0.01508795 -0.6373212  -1 ...

# %%
fig = px.histogram(df, x='question', color='answer')
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <div>
#
#
#             <div id="99567784-c8cb-4f9f-97cf-cb0898c54236" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("99567784-c8cb-4f9f-97cf-cb0898c54236")) {
#                     Plotly.newPlot(
#                         '99567784-c8cb-4f9f-97cf-cb0898c54236',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "answer=preventing possible spread of COVID - 19 while allowing for continued patient care<br>question=%{x}<br>count=%{y}", "legendgroup": "preventing possible spread of COVID - 19 while allowing for continued patient care", "marker": {"color": "#636efa"}, "name": "preventing possible spread of COVID - 19 while allowing for continued patient care", "offsetgroup": "preventing possible spread of COVID - 19 while allowing for continued patient care", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["How does telemedicine help manage the disease?"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "answer=enable patients to connect with their healthcare provider at a distance<br>question=%{x}<br>count=%{y}", "legendgroup": "enable patients to connect with their healthcare provider at a distance", "marker": {"color": "#EF553B"}, "name": "enable patients to connect with their healthcare provider at a distance", "offsetgroup": "enable patients to connect with their healthcare provider at a distance", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["How does telemedicine help manage the disease?"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "answer=Due to reduced outpatient capacity and the need to minimize non - urgent trips to the hospital, we have implemented telemedicine and have leveraged on partnerships with school counselors and other community partners<br>question=%{x}<br>count=%{y}", "legendgroup": "Due to reduced outpatient capacity and the need to minimize non - urgent trips to the hospital, we have implemented telemedicine and have leveraged on partnerships with school counselors and other community partners", "marker": {"color": "#00cc96"}, "name": "Due to reduced outpatient capacity and the need to minimize non - urgent trips to the hospital, we have implemented telemedicine and have leveraged on partnerships with school counselors and other community partners", "offsetgroup": "Due to reduced outpatient capacity and the need to minimize non - urgent trips to the hospital, we have implemented telemedicine and have leveraged on partnerships with school counselors and other community partners", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["How does telemedicine help manage the disease?"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "answer=telemedicine consultations and return visits were recommended when resources / staff available<br>question=%{x}<br>count=%{y}", "legendgroup": "telemedicine consultations and return visits were recommended when resources / staff available", "marker": {"color": "#ab63fa"}, "name": "telemedicine consultations and return visits were recommended when resources / staff available", "offsetgroup": "telemedicine consultations and return visits were recommended when resources / staff available", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["How does telemedicine help manage the disease?"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "answer=outbreak alert and response network<br>question=%{x}<br>count=%{y}", "legendgroup": "outbreak alert and response network", "marker": {"color": "#FFA15A"}, "name": "outbreak alert and response network", "offsetgroup": "outbreak alert and response network", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["How does telemedicine help manage the disease?"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "answer=to bring medical care to patients<br>question=%{x}<br>count= ...

# %% [markdown]
# #A Telemedicine Bubble?
#
# It might be the case that telemedicine is experiencing a bubble which will burst post-COVID-19. Under normal circumstances, regulations and pricing issues might stifle its growth as it has been the case so far. The technology might recede back into oblivion, only to rise up during the next outbreak.
#
# However, another global public health crisis is likely to happen. In less than a decade we’ve seen the likes of MERS, Ebola, Zika virus and COVID-19. The latest one has shown the importance of telemedicine and key stakeholders should embrace the technology and make it an integral part of the healthcare system. This will help work towards the digital health agenda while also preparing for an eventual emergency.
# https://medicalfuturist.com/covid-19-was-needed-for-telemedicine-to-finally-go-mainstream/

# %%
px.histogram(df, x='title', color='section')
# Out:
# <div>
#
#
#             <div id="27683837-d4f7-4636-aea7-23981cece3f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("27683837-d4f7-4636-aea7-23981cece3f2")) {
#                     Plotly.newPlot(
#                         '27683837-d4f7-4636-aea7-23981cece3f2',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "section=abstract<br>title=%{x}<br>count=%{y}", "legendgroup": "abstract", "marker": {"color": "#636efa"}, "name": "abstract", "offsetgroup": "abstract", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["The effective use of telemedicine to save lives and maintain structure in a healthcare system: Current response to COVID-1", "COVID-19 and Telemedicine: Immediate action required for maintaining healthcare providers well-being", "Caring for children and adolescents with eating disorders in the current COVID-19 pandemic: A Singapore perspective", "Prostate Cancer Radiotherapy Recommendations in Response to COVID-19", "From Isolation to Coordination: How Can Telemedicine Help Combat the COVID-19 Outbreak?", "Telemedicine in the Time of Coronavirus", "Telemedicine for Diabetes Care in India during COVID19 Pandemic and National Lockdown Period: Guidelines for Physicians", "Short-term Forecasts of the COVID-19 Epidemic in Guangdong and Zhejiang, China: February 13\u201323, 2020", "COVID-19 and Telemedicine: Immediate action required for maintaining healthcare providers well-being", "Out-of-Hospital Cohort Treatment of Coronavirus Disease 2019 Patients with Mild Symptoms in Korea: an Experience from a Single Community Treatment Center", "Caring for children and adolescents with eating disorders in the current COVID-19 pandemic: A Singapore perspective", "Upheaval in cancer care during the COVID-19 outbreak", "Predicting the evolution and control of COVID-19 pandemic in Portugal."], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "section=body_text/discussion<br>title=%{x}<br>count=%{y}", "legendgroup": "body_text/discussion", "marker": {"color": "#EF553B"}, "name": "body_text/discussion", "offsetgroup": "body_text/discussion", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Caring for children and adolescents with eating disorders in the current COVID-19 pandemic: A Singapore perspective"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "section=body_text/conclusion<br>title=%{x}<br>count=%{y}", "legendgroup": "body_text/conclusion", "marker": {"color": "#00cc96"}, "name": "body_text/conclusion", "offsetgroup": "body_text/conclusion", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["A model for COVID-19 prediction in Iran based on China parameters", "Effectiveness and cost-effectiveness of public health measures to control COVID-19: a modelling study", "The effect of control strategies that reduce social mixing on outcomes of the COVID-19 epidemic in Wuhan, China", "Prediction of the Epidemic of COVID-19 Based on Quarantined Surveillance in China", "Predicting the epidemic trend of COVID-19 in China and across the world using the machine learning approach", "Utilize State Transition Matrix Model to Predict the Novel Corona Virus Infection Peak and Patient Distribution"], "xaxis": "x", "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"title": {"text": "section"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {" ...

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQF1kmrgQ85B1vanO_F-7BLF8rRW9pvuDrQh0hcOYqRWS3qJrsp&usqp=CAU',width=400,height=400)
# Out:
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQF1kmrgQ85B1vanO_F-7BLF8rRW9pvuDrQh0hcOYqRWS3qJrsp&usqp=CAU" width="400" height="400"/>

# %% [markdown]
# Kaggle Notebook Runner: Marília Prata  @mpwolke
